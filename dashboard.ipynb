# %%
# %load_ext autoreload
# %autoreload 3
from engine import CricketAnalyzer
from interface import TraderCockpit
import pandas as pd

# Initialize with the Master Data
bot = CricketAnalyzer('data/FINAL_ODI_MASTER.csv')

# Launch UI
app = TraderCockpit(bot)
app.display()
# Out:
# c:\Users\khaisar jaha\OneDrive\Desktop\Cricket_Project\ai\gemini_client.py:1: FutureWarning:
#
# All support for the `google.generativeai` package has ended. It will no longer be receiving
# updates or bug fixes. Please switch to the `google.genai` package as soon as possible.
# See README for more details:
#
# https://github.com/google-gemini/deprecated-generative-ai-python/blob/main/README.md
#
#   import google.generativeai as genai
# ⚙️ Initializing Smart Engine (v2.0 - Modular)...
# 📂 Loading Database: data/FINAL_ODI_MASTER.csv
#    Raw Data: 317658 balls loaded (Sorted by Date).
# ✅ Player Data Loaded: 110975 stats rows.
#    🔨 Building Match Summary...
#    🔧 Auto-Fixing Ambiguous Venues...
#    🧠 Applying Smart Venue Matching (Exact -> Substring -> Fuzzy)...
# ✅ Engine Ready! Condensed into 600 unique matches.
# VBox(children=(HTML(value='<h2>🏏 Algo-Trader Dashboard</h2>'), HTML(value='<i>Start typing a venue name or sel…
