# %%
# %load_ext autoreload
# %autoreload 3
from engine import CricketAnalyzer
from interface import TraderCockpit
import pandas as pd

bot = CricketAnalyzer('data/FINAL_ODI_MASTER.csv')
app = TraderCockpit(bot)
app.display()
# Out:
# ⚙️ Initializing Smart Engine...
# 📂 Loading Database: data/FINAL_ODI_MASTER.csv
#    Raw Data: 317658 balls loaded.
#    🔨 Building Match Summary (Filtering Super Overs)...
#    🔧 Auto-Fixing Ambiguous Venues...
#    ✅ Venue Ambiguities Resolved.
#    🧠 Applying Smart Venue Matching (Clean -> Substring -> Fuzzy)...
#    ✅ Venues Standardized! Total Unique Grounds: 92
# ✅ Engine Ready! Condensed into 600 unique matches.
#    Date Range: 2016 to 2025
# ...
