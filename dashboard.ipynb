# %%
# %load_ext autoreload
# %autoreload 2
from engine import CricketAnalyzer
from interface import TraderCockpit

bot = CricketAnalyzer('data/FINAL_ODI_MASTER.csv')
app = TraderCockpit(bot)
app.display()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ⚙️ Initializing Engine...
# 📂 Loading Database: data/FINAL_ODI_MASTER.csv
#    Raw Data: 1327866 balls loaded.
#    🔨 Building Match Summary (Filtering Super Overs)...
# ✅ Engine Ready! Condensed into 2504 unique matches.
#    Date Range: 2002 to 2025
# VBox(children=(HTML(value='<h2>🏏 Algo-Trader Dashboard</h2>'), HTML(value='<i>Start typing a venue name to see…
