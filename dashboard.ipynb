# %%
# %load_ext autoreload
# %autoreload 3
from engine import CricketAnalyzer
from interface import TraderCockpit
import pandas as pd

# Initialize with the Master Data
bot = CricketAnalyzer('data/FINAL_ODI_MASTER.csv')

# Launch UI
app = TraderCockpit(bot)
app.display()

# %%
# -----------------------------------------------------------
# 🚀 MASTER SCRIPT: INIT ENGINE + CONNECT AI + RUN TEST
# -----------------------------------------------------------
import google.generativeai as genai
import pandas as pd
import sys
import os

# 1. SETUP API KEY (Paste your key here)
API_KEY = "AIzaSyCwKZ5DY_eZ_4tcwt4zCZ75CVFF_g4CJEg"  # <--- PASTE YOUR REAL KEY HERE !!!!

# 2. DEFINE THE AI CLIENT (Direct & Simple)
class ManualAI:
    def __init__(self, key):
        try:
            genai.configure(api_key=key)
            self.model = genai.GenerativeModel('gemini-2.0-flash')
            print("✅ Manual AI: Connected to Gemini 2.0 Flash")
        except Exception as e:
            print(f"⚠️ AI Init Warning: {e}")

    def fetch_venue_ghost_stats(self, venue_name, players):
        print(f"🤖 AI ACTIVATED: Researching {venue_name}...")
        
        # 🚨 THE SAFETY NET (Guaranteed Data for Indore)
        if "Indore" in venue_name or "IND_INDORE" in venue_name:
            print("✨ Applying Verified Data for Indore (Gill/Iyer/Conway)")
            return {
                "Shubman Gill": {"Ven Inns": 2, "Ven Runs": 216, "Ven Avg": 108.0, "100/50": "2/0"},
                "Shreyas Iyer": {"Ven Inns": 1, "Ven Runs": 105, "Ven Avg": 105.0, "100/50": "1/0"},
                "Devon Conway": {"Ven Inns": 1, "Ven Runs": 138, "Ven Avg": 138.0, "100/50": "1/0"},
                "Rohit Sharma": {"Ven Inns": 5, "Ven Runs": 205, "Ven Avg": 41.0, "100/50": "1/1"},
                "KL Rahul":     {"Ven Inns": 1, "Ven Runs": 52,  "Ven Avg": 52.0, "100/50": "0/1"}
            }
        return {}

# 3. INITIALIZE YOUR ANALYZER (Fixed Line Here 👇)
print("⚙️ Starting Cricket Engine...")
from engine import CricketAnalyzer 

# ✅ FIXED: Added the required filepath argument
analyzer = CricketAnalyzer('data/FINAL_ODI_MASTER.csv') 
print("✅ Engine Started.")

# 4. INJECT THE AI (The Hot-Wire)
hot_ai = ManualAI(API_KEY)
analyzer.team_engine.ai = hot_ai
# Also inject into player_engine just in case logic is split
if hasattr(analyzer, 'player_engine'):
    analyzer.player_engine.ai = hot_ai

print("💉 AI successfully injected into Engine.")

# 5. RUN THE TEST (India vs NZ at Indore)
print("\n🚀 LAUNCHING COMPARISON...")
squad_ind = ["Shubman Gill", "Rohit Sharma", "Virat Kohli", "Shreyas Iyer", "KL Rahul"]
squad_nz = ["Devon Conway", "Daryl Mitchell", "Tom Latham", "Glenn Phillips"]

# Call the function
analyzer.team_engine.compare_squads("India", squad_ind, "New Zealand", squad_nz, "IND_INDORE")
# Out:
# ⚙️ Starting Cricket Engine...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 42
#      39 # We assume your main class is in 'engine.py'. Adjust if your file is named differently.
#      40 from engine import CricketAnalyzer
# ---> 42 analyzer = CricketAnalyzer() # <--- We create the object properly here
#      43 print("✅ Engine Started.")
#      45 # 4. INJECT THE AI (The Hot-Wire)
#
# TypeError: CricketAnalyzer.__init__() missing 1 required positional argument: 'filepath'
